# %% [markdown]
# # Import des données

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.feature_extraction.text import CountVectorizer
import sklearn.model_selection as ms
import matplotlib.pyplot as plt
import os
import re
import datetime
import sys
# %matplotlib inline

# %%
def displayUniqueCount(series):
    data = np.unique(series, return_counts=True)
    df = pd.DataFrame(
        data = {'Valeur':data[0], 'Nombre':data[1]},
        columns = ['Valeur', 'Nombre'])
    df.sort_values(by ="Nombre", ascending=False, inplace=True)
    return df

# %%
ROOT_DIR = os.getcwd()
DATA ='data_challenge'
DATA_DIR = os.path.join(ROOT_DIR, DATA)
TRAIN="train"
TEST="test"
SOURCE="source"
TARGET="prix"

# %%
train = pd.read_csv(os.path.join(DATA_DIR, 'boites_medicaments_train.csv'),
                    encoding='utf-8',
                    sep=';')

test = pd.read_csv(os.path.join(DATA_DIR, 'boites_medicaments_test.csv'),
                   encoding='utf-8', 
                   sep=';')

train[SOURCE] = TRAIN
test[SOURCE] = TEST
BIG = pd.concat([train, test], axis=0)

# %% [markdown]
# # Preparation des donnees

# %% [markdown]
# ### Types de features

# %%
# features numériques
feat_num = ['libelle_plaquette', 'libelle_ampoule', 'libelle_flacon', 
            'libelle_tube', 'libelle_stylo', 'libelle_seringue',
            'libelle_pilulier', 'libelle_sachet', 'libelle_comprime', 
            'libelle_gelule', 'libelle_film', 'libelle_poche',
            'libelle_capsule'] + ['nb_plaquette', 'nb_ampoule', 
            'nb_flacon', 'nb_tube', 'nb_stylo', 'nb_seringue',
            'nb_pilulier', 'nb_sachet', 'nb_comprime', 'nb_gelule', 
            'nb_film', 'nb_poche', 'nb_capsule', 'nb_ml']
# features date
feat_dates = ['date declar annee', 'date amm annee']
# features catégorielles
feat_cat = ['statut', 'etat commerc', 'agrement col', 'tx rembours',
           'statut admin', 'type proc']
# features texte
feat_text = ['libelle', 'titulaires', 'substances', 'forme pharma', 'voies admin']


featToDel = ['libelle', 'id'] #,'voies admin_NB','substances_NB'
featToDummy = feat_cat
featToDummy.remove('tx rembours')
featToDummy.extend(['forme pharma'])
featToEncode = []
featToTransform = [ "convertTx", "log", "voies_admin", "substance", "titulaire"] #"buildBIG",, "new_libelle"

config = {"featToDel":featToDel,
          "featToDummy":featToDummy,
          "featToEncode":featToEncode,
          "featToTransform":featToTransform}

print "DELETE    :  ", featToDel
print "DUMMY     :  ", featToDummy
print "ENCODE    :  ", featToEncode
print "TRANSFORM :  ", featToTransform
# Out:
# DELETE    :   ['libelle', 'id']
# DUMMY     :   ['statut', 'etat commerc', 'agrement col', 'statut admin', 'type proc', 'forme pharma']
# ENCODE    :   []
# TRANSFORM :   ['convertTx', 'log', 'voies_admin', 'substance', 'titulaire']

# %% [markdown]
# ### Feature Engineering : LIBELLE

# %%
def addNBLibelle(val, X):
    regexp = re.compile("([0-9]{1,5})\s" + val + "*")
    X["nb_" + val] = X.libelle.apply(lambda w : regexp.search(w).group(1) if regexp.search(w) else 0)
    X["libelle_" + val] = X.libelle.apply(lambda w : 1 if regexp.search(w) else 0)
    return X

# %% [markdown]
# ### Feature Engineering : SUBSTANCES - VOIES ADMIN

# %% [markdown]
# Création du Bag of words substances

# %%
def create_column(X, name):

    distinctCategs = (X[name]
                      .apply(lambda col_value : col_value.split(','))
                      .apply(pd.Series)
                      .unstack()
                      .dropna()
                      .str.strip()
                      .unique())

    #pd.DataFrame(distinctCategs).to_csv("distinctCateg"+name +".csv", encoding="utf-8", sep=";")
    
    for distinctCateg in distinctCategs:
        X[distinctCateg] = X[name].apply(lambda x : 1 if distinctCateg in x else 0)
        
    X[name + "_NB"] = X[distinctCategs].sum(axis=1)
    
    print "Add " + str(len(distinctCategs)) + " new columns"
    return X

# %% [markdown]
# ### Feature Engineering : SUBSTANCES

# %%
def transfo_substances(X, index):

    X = (X
         .apply(lambda subs: re.sub(r'(\([^)]*\))','', subs))
         .apply(lambda subs: subs.replace("é","e"))
         .apply(lambda subs: subs.replace("es","e"))
         .apply(lambda subs: subs.replace("ee","e"))
         .apply(lambda subs: subs.replace("-",""))
         .apply(lambda subs: subs.replace("doxyxycline", "doxycycline"))
         .apply(lambda subs: subs.replace("alpha", "alfa")))
    
    stop_words={"d", "de", "des","du","à","10a","11","11a","12f","1331","135","13c","14","158","15b","16","165","175","179a",
            "17f","18","181","18c","197","19a","19f","1a","1b","20","2009","2010","2011","2013","2014","22f","23f","27","2a",
            "2b","3073","326f","3350","33f","361","39","4000","4385","55","6a","6b","74xp","7f","88","940","9715293",
            "974p","980","9n","9v", "extrait","allergenique", "humaine", "recombinante", "conjuguee", "la", "extrait",
            "fruit", "proteine", "vectrice", "des","en", "gel","gomme","venin", "proteine", "recombinante", "adsorbee",
            "virus", "humain", "hpv", "type", "proteines", "pre", "purifiee", "souche", "ra", "vivant", "riche", "sec",
            "ab", "et", "polyoside", "serotypes", "conjugues","vectrice","attendue","utilisee", "synthetique", "oxyde", 
            "base", "acide","acides", "actif","active", "adjuvant", "adsorbe", "afrique","ecorce", "mou", "fusion",
            "groupe", "chaine", "agglomere", "cire", "element", "especes", "excipient", "externe", "forme", "glacial", 
            "leger", "lourd", "chlorhydrate", "sodique","hydrochlorothiazide","anhydre"}

    vectorizer = CountVectorizer(min_df=0., max_df=1.0, stop_words=stop_words, strip_accents="ascii")
    SUBS_VECT = vectorizer.fit_transform(X)
    feat_names = vectorizer.get_feature_names()

    return pd.DataFrame(data=SUBS_VECT.A, columns=feat_names, index= index)

# %% [markdown]
# ### Encodage des features catégorielles
#
# Les algorithmes de machine learning s'attendent à avoir en entrée des nombres, et non pas des chaînes de caractères. C'est pourquoi nous transformons les features catégorielles en nombres, à l'aide de LabelEncoder()

# %%
def parse(X, config, silent=False) :
    start = datetime.datetime.today().now()
    if not silent:
        print '__________________________________________ PARSE __________________________________________'
        print '--> ', start.strftime('%d-%m-%Y : %H:%M')
        print 'BEFORE : ', X.shape
    
    if "titulaire" in config["featToTransform"]:
        print "Split titulaires to titulaire and country"
        X["titulaires"] = (X["titulaires"]
                      .apply(lambda col_value : col_value.replace('LABORATOIRES',''))
                      .apply(lambda col_value : col_value.replace('BRISTOL-MYERS',' BRISTOL MYERS'))
                      .apply(lambda col_value : col_value.replace('SANOFI-AVENTIS','SANOFI AVENTIS'))
                      .str.strip()
                      .apply(lambda substance : substance.split(' ')[0] )
                      .apply(pd.Series))
        config["featToEncode"].extend(['titulaires'])

    if "substance" in config["featToTransform"]:
        print "Create a Substance column for each substance"
        X["substances"] = (X["substances"]
                           .apply(lambda subs: re.sub(r'(\([^)]*\))','', subs))
                           .apply(lambda subs: subs.replace("es","e"))
                           .apply(lambda subs: subs.replace("ee","e"))
                           .apply(lambda subs: subs.replace("doxyxycline", "doxycycline"))
                           .apply(lambda subs: subs.replace("alpha", "alfa")))
        X = create_column(X, "substances")
        X.drop("substances", axis =1, inplace=True)
    
    if "voies_admin" in config["featToTransform"]:
        print "Create a Voie Admin column for each voie admin"
        X = create_column(X, "voies admin")
        X.drop("voies admin", axis =1, inplace=True)
        
    if "convertTx" in config["featToTransform"]:
        print "convert tx rembours"
        X["tx rembours"] = [int(x.replace("%", "")) for x in X["tx rembours"]]
    
    if "fillNR" in config["featToTransform"]:
        print "---Fill NR "
        X = fillNR(X)
        
    if "new_libelle" in config["featToTransform"]:
        lib_to_add = ["cartouche","bouteille","film","inhalateur"]
        for lib in lib_to_add:
            X = addNBLibelle(lib, X)
    
    #remove target
    y_train = X.loc[X.source == 'train',TARGET]
    
    if "log" in config["featToTransform"]:
        y_train = y_train.apply(np.log)
                    
    del X[TARGET]
    
    print "---Feature to encode "
    #Feature to encode
    featToEncode = config["featToEncode"]
    for encodeToCat in featToEncode:
        print "encode " + encodeToCat
        le = LabelEncoder()
        le.fit(X[encodeToCat])
        X.loc[:,encodeToCat] = le.transform(X[encodeToCat])
    
    print "---Feature to dummy "
    #Feature to dummy
    featToDummy = config["featToDummy"]
    if featToDummy:
        dums = pd.get_dummies(X[featToDummy]).astype(int)
        X = pd.concat([X, dums], axis=1)
        X.drop(featToDummy, axis =1, inplace=True)
    
    print "---Feature to delete "
    #Feature to delete
    featToDel = config["featToDel"]
    X.drop(featToDel, axis =1, inplace=True)
    
    if "buildBIG" in config["featToTransform"]:
        print "---Build BIG.csv " 
        X.to_csv(DATA_DIR + '/'+ 'BIG.csv', header=True, index=False,sep=';', encoding='utf-8')
    
    X_train = X[X[SOURCE] == TRAIN]
    X_test = X[X[SOURCE] == TEST]    
    del X_test[SOURCE]
    del X_train[SOURCE]
    
    
    if not silent:
        print '%s Elapsed time :%d s' % (datetime.datetime.today().now().strftime('--> %d-%m-%Y : %H:%M'), 
        (datetime.datetime.today().now().now() - start).total_seconds())
        print 'AFTER TRAIN :', X_train.shape
        print 'AFTER TEST :', X_test.shape
        sys.stdout.flush()
    
    return X_train, X_test, y_train

# %%
X_train, X_test, y_train = parse(BIG.copy(), config)
# Out:
# __________________________________________ PARSE __________________________________________
# -->  27-10-2016 : 17:47
# BEFORE :  (12235, 43)
# Split titulaires to titulaire and country
# Create a Substance column for each substance
# Add 1739 new columns
# Create a Voie Admin column for each voie admin
# Add 45 new columns
# convert tx rembours
# ---Feature to encode
# encode titulaires
# ---Feature to dummy
# ---Feature to delete
# --> 27-10-2016 : 17:47 Elapsed time :21 s
# AFTER TRAIN : (8564, 2053)
# AFTER TEST : (3671, 2053)

# %% [markdown]
# # Creation d'un modele

# %% [markdown]
# ### Métrique MAPE

# %%
# Mean Absolute Percentage Error
def mape_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# ### Cross validation

# %%
def crossVal (X, y, clf, scorer, n_splits=10, shuffle = False) :
    folds= ms.KFold(n_splits=n_splits, shuffle= shuffle, random_state=None) #shuffle = False, random_state
    # When shuffle=True, pseudo-random number generator state used for shuffling.
    # If None, use default numpy RNG for shuffling
    
    scoreList = []
    i = 0
    for trainIdx, testIdx in folds.split(X):
        i +=1 
        XTrainFolds = None; XTestFolds = None; yTrainFolds= None; yTestFolds= None
        yPred = []
        XTrainFolds, XTestFolds = X.iloc[trainIdx], X.iloc[testIdx]
        yTrainFolds, yTestFolds = y.iloc[trainIdx], y.iloc[testIdx]
        clf = clf.fit(XTrainFolds, yTrainFolds)
        res = clf.predict(XTestFolds)
        
        if "log" in config["featToTransform"]:
            score = scorer(np.exp(yTestFolds), np.exp(res))
        else:
            score = scorer(yTestFolds, res)
        
        scoreList.append(score)
        print "*** MAPE Error : " + str(i) + " - " + str(score)
        sys.stdout.flush()
        
    print "----------------"
    print "  - Mean :" + str(np.mean(scoreList))
    print "  - Ecart Max-Min :" + str(np.max(scoreList) - np.min(scoreList))

# %%
clf = ExtraTreesRegressor(n_estimators=11, max_features= 'auto', criterion="mse", max_depth=None, min_samples_split=5, n_jobs=-1)
#If “auto”, then max_features=n_features.
#paramsET = {'n_jobs': -1, 'silent': 1, 'n_estimators': 50, 'max_features': 'auto', 'min_samples_split': 5.0, 'max_depth': 30}
#clf = RandomForestRegressor(n_estimators = int(paramsET['n_estimators']), n_jobs = -1, verbose = 0)

#clf = GradientBoostingRegressor(verbose = 1, max_features='auto')

# %%
crossVal(X_train, y_train, clf, mape_error)
# Out:
# *** MAPE Error : 1 - 34.6072342524
# *** MAPE Error : 2 - 34.9123103139
# *** MAPE Error : 3 - 39.649395899
# *** MAPE Error : 4 - 31.7653116503
# *** MAPE Error : 5 - 30.4430226844
# *** MAPE Error : 6 - 38.5198550212
# *** MAPE Error : 7 - 33.9462645939
# *** MAPE Error : 8 - 31.651018609
# *** MAPE Error : 9 - 32.4795954816
# *** MAPE Error : 10 - 32.5675254986
# ----------------
#   - Mean :34.0541534004
#   - Ecart Max-Min :9.20637321465

# %%
print "Features sorted by their score:"
sorted(zip(map(lambda x: round(x, 4), clf.feature_importances_), X_train.columns), 
             reverse=True)
# Out:
# Features sorted by their score:
# [(0.1747, u'type proc_Proc\xe9dure centralis\xe9e'),
#  (0.1008, u'tx rembours'),
#  (0.0958, u'nb_comprime'),
#  (0.0001, u'forme pharma_g\xe9lule \xe0 lib\xe9ration modifi\xe9e'),
#  (0.0001, u'forme pharma_granul\xe9s \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0001, u'forme pharma_granul\xe9s enrob\xe9 en vrac'),
#  (0.0001, u'forme pharma_granul\xe9s'),
#  (0.0001, u'forme pharma_gel'),
#  (0.0001, u'forme pharma_empl\xe2tre m\xe9dicamenteux(se)'),
#  (0.0001,
#   u'forme pharma_comprim\xe9 s\xe9cable \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0001,
#   u'forme pharma_comprim\xe9 pellicul\xe9 \xe0 lib\xe9ration modifi\xe9e'),
#  (0.0001,
#   u'forme pharma_comprim\xe9 enrob\xe9 \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0001, u'forme pharma_comprim\xe9 enrob\xe9'),
#  (0.0001, u'forme pharma_comprim\xe9 effervescent(e) s\xe9cable'),
#  (0.0001, u'forme pharma_comprim\xe9 effervescent(e)'),
#  (0.0001,
#   u"etat commerc_Arr\xeat de commercialisation (le m\xe9dicament n'a plus d'autorisation)"),
#  (0.0001, u'ZIDOVUDINE'),
#  (0.0001, u'V\xc9RAPAMIL'),
#  (0.0001, u'VIRUS DE LA GRIPPE FRAGMENT\xc9'),
#  (0.0001, u'VENLAFAXINE'),
#  (0.0001, u'VALSARTAN'),
#  (0.0001, u'VALPROATE DE SODIUM'),
#  (0.0001, u'UR\xc9E [13C]'),
#  (0.0001, u'URAPIDIL'),
#  (0.0001, u'T\xc9RIPARATIDE'),
#  (0.0001, u'TR\xc9TINO\xcfNE'),
#  (0.0001, u'TRIMIPRAMINE BASE'),
#  (0.0001, u'TRIMIPRAMINE'),
#  (0.0001, u'TRIHEXYPH\xc9NIDYLE'),
#  (0.0001, u'TRANEXAMIQUE'),
#  (0.0001, u'TRAMADOL'),
#  (0.0001, u'TINZAPARINE SODIQUE'),
#  (0.0001, u'TIMOLOL'),
#  (0.0001, u'TICARCILLINE BASE'),
#  (0.0001, u'THIOCOLCHICOSIDE'),
#  (0.0001, u'THIAMAZOLE'),
#  (0.0001, u'TESTOST\xc9RONE'),
#  (0.0001, u'TERBUTALINE'),
#  (0.0001, u'TELMISARTAN'),
#  (0.0001, u'TAZOBACTAM SODIQUE'),
#  (0.0001, u'TAZOBACTAM'),
#  (0.0001, u'TAMSULOSINE'),
#  (0.0001, u'TACALCITOL'),
#  (0.0001, u'S\xc9V\xc9LAMER'),
#  (0.0001, u'S\xc9RINE'),
#  (0.0001, u'S\xc9L\xc9GILINE'),
#  (0.0001, u'SUMATRIPTAN'),
#  (0.0001, u'SULPIRIDE'),
#  (0.0001, u'SULFATE DE MORPHINE'),
#  (0.0001, u'SULFAM\xc9THOXAZOLE'),
#  (0.0001, u'SUCCINATE DE SOLIF\xc9NACINE'),
#  (0.0001, u'SERTRALINE BASE'),
#  (0.0001, u'SERTRALINE'),
#  (0.0001, u'RUFINAMIDE'),
#  (0.0001, u'ROSUVASTATINE'),
#  (0.0, u"\xc9THYLSUCCINATE D'\xc9RYTHROMYCINE"),
#  (0.0, u'\xc9THYLMORPHINE'),
#  (0.0, u'\xc9THOSUXIMIDE'),
#  (0.0, u'\xc9THANOLATE DE DARUNAVIR'),
#  (0.0, u'\xc9TANERCEPT'),
#  (0.0, u'\xc9SOM\xc9PRAZOLE MAGN\xc9SIUM TRIHYDRAT\xc9'),
#  (0.0, u'\xc9SOM\xc9PRAZOLE MAGN\xc9SIQUE TRIHYDRAT\xc9'),
#  (0.0, u'\xc9SOM\xc9PRAZOLE MAGN\xc9SIQUE DIHYDRAT\xc9'),
#  (0.0, u'\xc9SOM\xc9PRAZOLE'),
#  (0.0, u'\xc9RYTHROMYCINE DIHYDRAT\xc9E'),
#  (0.0, u'\xc9RYTHROMYCINE BASE'),
#  (0.0, u'\xc9RYTHROMYCINE'),
#  (0.0, u'\xc9RYSIMUM'),
#  (0.0, u'\xc9PROSARTAN'),
#  (0.0, u'\xc9PO\xc9TINE TH\xcaTA'),
#  (0.0, u'\xc9POLAMINE DE DICLOF\xc9NAC'),
#  (0.0, u'\xc9PIRUBICINE'),
#  (0.0, u'\xc9PINASTINE'),
#  (0.0, u'\xc9NOXAPARINE SODIQUE'),
#  (0.0, u'\xc9NOXACINE SESQUIHYDRAT\xc9'),
#  (0.0, u'\xc9NOXACINE ANHYDRE'),
#  (0.0, u'\xc9NANTATE DE TESTOST\xc9RONE'),
#  (0.0, u'\xc9L\xc9TRIPTAN'),
#  (0.0, u'\xc9FAVIRENZ'),
#  (0.0, u'\xc9CONAZOLE BASE'),
#  (0.0, u'\xc9CONAZOLE'),
#  (0.0, u'voie parent\xe9rale autre'),
#  (0.0, u'vaginale'),
#  (0.0, u'ur\xe9trale'),
#  (0.0, u'statut_Pr\xe9sentation active'),
#  (0.0, u'statut_Pr\xe9sentation abrog\xe9e'),
#  (0.0, u'statut admin_Autorisation suspendue'),
#  (0.0, u'statut admin_Autorisation retir\xe9e'),
#  (0.0, u'p\xe9rioculaire'),
#  (0.0, u'p\xe9rineurale'),
#  (0.0, u'p\xe9ridurale'),
#  (0.0, u'p\xe9riarticulaire'),
#  (0.0, u'nb_film'),
#  (0.0, u'intravitr\xe9enne'),
#  (0.0, u'intras\xe9reuse'),
#  (0.0, u'intrap\xe9riton\xe9ale'),
#  (0.0, u'intral\xe9sionnelle'),
#  (0.0, u'intradurale'),
#  (0.0, u'intradermique'),
#  (0.0, u'intra-ut\xe9rine'),
#  (0.0, u'intra-murale'),
#  (0.0, u'intra cholangio-pancr\xe9atique'),
#  (0.0, u'infiltration'),
#  (0.0, u'gastro-ent\xe9rale'),
#  (0.0, u'gastrique'),
#  (0.0, u'forme pharma_\xe9mulsion pour perfusion'),
#  (0.0, u'forme pharma_\xe9mulsion pour application'),
#  (0.0, u'forme pharma_\xe9mulsion injectable pour perfusion'),
#  (0.0, u'forme pharma_\xe9mulsion fluide pour application'),
#  (0.0, u'forme pharma_\xe9mulsion et  solution et  solution pour perfusion'),
#  (0.0, u'forme pharma_syst\xe8me de diffusion'),
#  (0.0, u'forme pharma_suspension pour instillation'),
#  (0.0, u'forme pharma_suspension pour inhalation'),
#  (0.0, u'forme pharma_suspension par n\xe9buliseur pour inhalation'),
#  (0.0, u'forme pharma_suspension buvable \xe0 diluer'),
#  (0.0, u'forme pharma_suspension'),
#  (0.0, u'forme pharma_suppositoire s\xe9cable'),
#  (0.0, u'forme pharma_suppositoire effervescent(e)'),
#  (0.0, u'forme pharma_solution \xe0 diluer pour solution buvable'),
#  (0.0, u'forme pharma_solution \xe0 diluer injectable ou pour perfusion'),
#  (0.0,
#   u'forme pharma_solution \xe0 diluer et  solvant pour solution injectable'),
#  (0.0, u'forme pharma_solution pour pulv\xe9risation endo-buccal(e)'),
#  (0.0, u'forme pharma_solution pour pulv\xe9risation'),
#  (0.0, u'forme pharma_solution pour lavage'),
#  (0.0, u'forme pharma_solution pour instillation'),
#  (0.0, u'forme pharma_solution pour inhalation par n\xe9buliseur'),
#  (0.0, u'forme pharma_solution pour inhalation'),
#  (0.0, u'forme pharma_solution pour bain de bouche'),
#  (0.0, u'forme pharma_solution pour application \xe0 diluer'),
#  (0.0, u'forme pharma_solution pour application st\xe9rile'),
#  (0.0, u'forme pharma_solution pour application moussant(e)'),
#  (0.0, u'forme pharma_solution pour administration endonasale'),
#  (0.0, u'forme pharma_solution ou'),
#  (0.0, u'forme pharma_solution moussant(e)'),
#  (0.0, u'forme pharma_solution injectable ou pour perfusion'),
#  (0.0, u'forme pharma_solution injectable hypertonique'),
#  (0.0, u'forme pharma_solution injectable et buvable'),
#  (0.0, u'forme pharma_solution gouttes'),
#  (0.0, u'forme pharma_solution filmog\xe8ne pour application'),
#  (0.0, u'forme pharma_solution et  \xe9mulsion et  solution pour perfusion'),
#  (0.0, u'forme pharma_solution et  solution pour perfusion'),
#  (0.0, u'forme pharma_solution et  solution injectable'),
#  (0.0, u'forme pharma_solution et  solution et  \xe9mulsion pour perfusion'),
#  (0.0, u'forme pharma_solution buvable ou'),
#  (0.0, u'forme pharma_solution buvable gouttes'),
#  (0.0, u'forme pharma_solution buvable et injectable'),
#  (0.0, u'forme pharma_solution'),
#  (0.0, u'forme pharma_p\xe2te pour application'),
#  (0.0, u'forme pharma_p\xe2te'),
#  (0.0,
#   u'forme pharma_poudre pour suspension pour administration intrav\xe9sicale'),
#  (0.0, u'forme pharma_poudre pour suspension ou'),
#  (0.0, u'forme pharma_poudre pour suspension et'),
#  (0.0, u'forme pharma_poudre pour suspension'),
#  (0.0, u'forme pharma_poudre pour solution pour irrigation v\xe9sical(e)'),
#  (0.0, u'forme pharma_poudre pour solution buvable et gastro-ent\xe9rale'),
#  (0.0, u'forme pharma_poudre pour solution buvable ent\xe9ral(e)'),
#  (0.0, u'forme pharma_poudre pour solution'),
#  (0.0, u'forme pharma_poudre pour inhalation et  poudre pour inhalation'),
#  (0.0, u'forme pharma_poudre pour inhalation en g\xe9lule'),
#  (0.0, u'forme pharma_poudre pour inhalation'),
#  (0.0, u'forme pharma_poudre pour a\xe9rosol et pour usage parent\xe9ral'),
#  (0.0, u'forme pharma_poudre pour application'),
#  (0.0, u'forme pharma_poudre et  suspension pour suspension injectable'),
#  (0.0, u'forme pharma_poudre et  solvant pour suspension pour instillation'),
#  (0.0,
#   u'forme pharma_poudre et  solvant pour suspension pour administration intrav\xe9sicale'),
#  (0.0, u'forme pharma_poudre et  solvant pour suspension injectable'),
#  (0.0, u'forme pharma_poudre et  solvant pour solution pour perfusion'),
#  (0.0,
#   u'forme pharma_poudre et  solvant pour solution injectable ou pour perfusion'),
#  (0.0, u'forme pharma_poudre et  solvant pour pr\xe9paration injectable'),
#  (0.0, u'forme pharma_poudre et  solvant pour inhalation par n\xe9buliseur'),
#  (0.0, u'forme pharma_poudre et  solvant pour dispersion injectable'),
#  (0.0, u'forme pharma_poudre et  solvant pour collyre en solution'),
#  (0.0, u'forme pharma_poudre et  solvant'),
#  (0.0, u'forme pharma_poudre et  solution pour usage parent\xe9ral'),
#  (0.0, u'forme pharma_poudre et  solution pour solution injectable'),
#  (0.0, u'forme pharma_poudre et  solution pour pr\xe9paration injectable'),
#  (0.0, u'forme pharma_poudre et  poudre pour solution buvable'),
#  (0.0, u'forme pharma_poudre effervescent(e) pour suspension buvable'),
#  (0.0, u'forme pharma_poudre effervescent(e) pour solution buvable'),
#  (0.0, u'forme pharma_poudre buvable pour suspension'),
#  (0.0, u'forme pharma_poudre buvable pour solution'),
#  (0.0, u'forme pharma_poudre buvable effervescent(e) pour suspension'),
#  (0.0, u'forme pharma_pommade pour application'),
#  (0.0, u'forme pharma_pilule enrob\xe9'),
#  (0.0, u'forme pharma_pansement adh\xe9sif(ve)'),
#  (0.0, u'forme pharma_ovule \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0, u'forme pharma_ovule'),
#  (0.0, u'forme pharma_mousse pour application'),
#  (0.0,
#   u'forme pharma_microsph\xe8re et  solution pour usage parent\xe9ral \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0, u'forme pharma_microgranule gastro-r\xe9sistant(e) en g\xe9lule'),
#  (0.0, u'forme pharma_microgranule gastro-r\xe9sistant(e)'),
#  (0.0, u'forme pharma_microgranule en comprim\xe9'),
#  (0.0, u'forme pharma_lyophilisat pour usage parent\xe9ral pour perfusion'),
#  (0.0, u'forme pharma_lyophilisat pour usage parent\xe9ral'),
#  (0.0, u'forme pharma_lyophilisat et  solvant pour collyre'),
#  (0.0, u'forme pharma_lyophilisat et  solution pour usage parent\xe9ral'),
#  (0.0, u'forme pharma_lotion pour application'),
#  (0.0, u'forme pharma_lotion'),
#  (0.0, u'forme pharma_implant injectable'),
#  (0.0, u'forme pharma_g\xe9lule et  g\xe9lule gastro-r\xe9sistant(e)'),
#  (0.0, u'forme pharma_g\xe9lule et  g\xe9lule'),
#  (0.0, u'forme pharma_granul\xe9s pour suspension buvable'),
#  (0.0, u'forme pharma_granul\xe9s pour solution buvable'),
#  (0.0, u'forme pharma_granul\xe9s pour sirop'),
#  (0.0,
#   u'forme pharma_granul\xe9s gastro-r\xe9sistant(e) pour suspension buvable'),
#  (0.0, u'forme pharma_granul\xe9s et  solvant pour suspension buvable'),
#  (0.0, u'forme pharma_granul\xe9s enrob\xe9'),
#  (0.0, u'forme pharma_granul\xe9s effervescent(e) pour solution buvable'),
#  (0.0, u'forme pharma_granul\xe9s buvable pour suspension'),
#  (0.0, u'forme pharma_granules'),
#  (0.0, u'forme pharma_gel\xe9e'),
#  (0.0, u'forme pharma_gel pour application'),
#  (0.0, u'forme pharma_dispositif et  dispositif'),
#  (0.0, u'forme pharma_cr\xe8me \xe9paisse pour application'),
#  (0.0, u'forme pharma_cr\xe8me pour application'),
#  (0.0, u'forme pharma_comprim\xe9 \xe0 sucer \xe0 croquer ou dispersible'),
#  (0.0, u'forme pharma_comprim\xe9 \xe0 sucer s\xe9cable'),
#  (0.0, u'forme pharma_comprim\xe9 \xe0 sucer ou \xe0 croquer'),
#  (0.0, u'forme pharma_comprim\xe9 \xe0 sucer'),
#  (0.0, u'forme pharma_comprim\xe9 \xe0 croquer ou \xe0 sucer'),
#  (0.0, u'forme pharma_comprim\xe9 \xe0 croquer ou dispersible'),
#  (0.0, u'forme pharma_comprim\xe9 s\xe9cable \xe0 lib\xe9ration modifi\xe9e'),
#  (0.0, u'forme pharma_comprim\xe9 s\xe9cable pour suspension buvable'),
#  (0.0, u'forme pharma_comprim\xe9 s\xe9cable pellicul\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 pour suspension buvable'),
#  (0.0,
#   u'forme pharma_comprim\xe9 pellicul\xe9 s\xe9cable \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0, u'forme pharma_comprim\xe9 pellicul\xe9 quadris\xe9cable'),
#  (0.0, u'forme pharma_comprim\xe9 pellicul\xe9 gastro-r\xe9sistant(e)'),
#  (0.0,
#   u'forme pharma_comprim\xe9 pellicul\xe9 et  granul\xe9s effervescent(e)'),
#  (0.0,
#   u'forme pharma_comprim\xe9 pellicul\xe9 et  comprim\xe9 pellicul\xe9 pellicul\xe9'),
#  (0.0,
#   u'forme pharma_comprim\xe9 pellicul\xe9 et  comprim\xe9 pellicul\xe9 et  comprim\xe9 pellicul\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 pellicul\xe9 et  comprim\xe9 pellicul\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 pellicul\xe9 dispersible'),
#  (0.0, u'forme pharma_comprim\xe9 ou \xe0 sucer \xe0 croquer'),
#  (0.0, u'forme pharma_comprim\xe9 osmotique \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0,
#   u'forme pharma_comprim\xe9 osmotique pellicul\xe9 \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0, u'forme pharma_comprim\xe9 orodispersible s\xe9cable'),
#  (0.0, u'forme pharma_comprim\xe9 orodispersible dispersible'),
#  (0.0, u'forme pharma_comprim\xe9 muco-adh\xe9sif'),
#  (0.0, u'forme pharma_comprim\xe9 et  comprim\xe9 pellicul\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 et  comprim\xe9 et  comprim\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 et  comprim\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 enrob\xe9 \xe0 croquer'),
#  (0.0, u'forme pharma_comprim\xe9 enrob\xe9 s\xe9cable'),
#  (0.0, u'forme pharma_comprim\xe9 enrob\xe9 gastro-r\xe9sistant(e)'),
#  (0.0,
#   u'forme pharma_comprim\xe9 enrob\xe9 et  comprim\xe9 enrob\xe9 et  comprim\xe9 enrob\xe9'),
#  (0.0,
#   u'forme pharma_comprim\xe9 enrob\xe9 et  comprim\xe9 enrob\xe9 enrob\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 enrob\xe9 et  comprim\xe9 enrob\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 drag\xe9ifi\xe9'),
#  (0.0, u'forme pharma_comprim\xe9 dispersible s\xe9cable'),
#  (0.0, u'forme pharma_comprim\xe9 dispersible ou \xe0 croquer'),
#  (0.0, u'forme pharma_comprim\xe9 dispersible orodispersible'),
#  (0.0, u'forme pharma_comprim\xe9 dispersible et orodispersible'),
#  (0.0, u'forme pharma_collyre \xe0 lib\xe9ration prolong\xe9e'),
#  (0.0, u'forme pharma_collyre en suspension'),
#  (0.0, u'forme pharma_capsule molle ou'),
#  (0.0, u'forme pharma_capsule molle gastro-r\xe9sistant(e)'),
#  (0.0, u'forme pharma_capsule'),
#  (0.0, u'etat commerc_D\xe9claration de suspension de commercialisation'),
#  (0.0, u'endotrach\xe9obronchique'),
#  (0.0, u'endosinusale'),
#  (0.0, u'endocanalaire'),
#  (0.0, u'buccogingivale'),
#  (0.0, u'auriculaire'),
#  (0.0, u'ZUCLOPENTHIXOL'),
#  (0.0, u'ZONISAMIDE'),
#  (0.0, u'ZOLPIDEM'),
#  (0.0, u'ZOF\xc9NOPRIL CALCIQUE'),
#  (0.0, u'ZOF\xc9NOPRIL'),
#  (0.0, u'ZINC  TRIHYDRAT\xc9'),
#  (0.0, u'ZINC  DIHYDRAT\xc9'),
#  (0.0, u'ZINC'),
#  (0.0, u'XINAFOATE DE SALM\xc9T\xc9ROL'),
#  (0.0, u'WARFARINE SODIQUE'),
#  (0.0,
#   u'V\xc9SICULES DE MEMBRANE EXTERNE  DE NEISSERIA MENINGITIDIS GROUPE B'),
#  (0.0, u'VIVANTE ATT\xc9NU\xc9E'),
#  (0.0, u'VIVANT'),
#  (0.0, u'VITAMINE D3'),
#  (0.0, u'VIRUS VARICELLE-ZONA SOUCHE OKA/MERCK'),
#  (0.0, u'VIRUS RUB\xc9OLEUX  ATT\xc9NU\xc9'),
#  (0.0, u'VIRUS POLIOMY\xc9LITIQUE SOUCHE SAUKETT DE TYPE 3 INACTIV\xc9'),
#  (0.0, u'VIRUS POLIOMY\xc9LITIQUE SOUCHE MEF-1 DE TYPE 2 INACTIV\xc9'),
#  (0.0, u'TOBRAMYCINE'),
#  (0.0, u'TI\xc9MONIUM'),
#  (0.0, u'TIXOCORTOL'),
#  (0.0, u'TIPRANAVIR'),
#  (0.0, u'TIOTROPIUM BASE'),
#  (0.0, u'TIOTROPIUM  MONOHYDRAT\xc9'),
#  (0.0, u'TIOPRONINE'),
#  (0.0, u'TIOCONAZOLE'),
#  (0.0, u'TINIDAZOLE'),
#  (0.0, u'TIMOLOL BASE'),
#  (0.0, u'TILUDRONIQUE'),
#  (0.0, u'TILUDRONATE DISODIQUE'),
#  (0.0, u'TILIQUINOL'),
#  (0.0, u'TILBROQUINOL'),
#  (0.0, u'TICARCILLINE SODIQUE'),
#  (0.0, u'TICAGR\xc9LOR'),
#  (0.0, u'TIAPRIDE BASE'),
#  (0.0, u'TIAPRIDE'),
#  (0.0, u'TIANEPTINE SODIQUE'),
#  (0.0, u'TIAGABINE ANHYDRE'),
#  (0.0, u'TIAGABINE  MONOHYDRAT\xc9'),
#  (0.0, u'TH\xc9OPHYLLINE MONOHYDRAT\xc9E'),
#  (0.0, u'TH\xc9OPHYLLINE ANHYDRE'),
#  (0.0, u'TH\xc9OPHYLLINE'),
#  (0.0, u'THIAMINE'),
#  (0.0, u'TETRAKISMETHANE'),
#  (0.0, u'TERTATOLOL'),
#  (0.0, u'TAZAROT\xc8NE'),
#  (0.0, u'TAURINE'),
#  (0.0, u'TARTRATE DE ZOLPIDEM'),
#  (0.0, u'TARTRATE DE BRIMONIDINE'),
#  (0.0, u"TARTRATE D'ADR\xc9NALINE"),
#  (0.0, u'TAMOXIF\xc8NE BASE'),
#  (0.0, u'TALC'),
#  (0.0, u'TACROLIMUS ANHYDRE'),
#  (0.0, u'TACALCITOL MONOHYDRAT\xc9'),
#  (0.0, u'S\xc9V\xc9LAMER BASE'),
#  (0.0, u'S\xc9L\xc9NITE DE SODIUM'),
#  (0.0, u'S\xc9L\xc9GILINE BASE'),
#  (0.0, u'SULINDAC'),
#  (0.0, u'SULFATE FERREUX'),
#  (0.0, u'SULFATE DE ZINC HEPTAHYDRAT\xc9'),
#  (0.0, u'SULFATE DE ZINC ANHYDRE'),
#  (0.0, u'SULFATE DE VINBLASTINE'),
#  (0.0, u'SULFATE DE TERBUTALINE'),
#  (0.0, u'SULFATE DE SODIUM ANHYDRE'),
#  (0.0, u'SULFATE DE PROTAMINE'),
#  (0.0, u'SULFATE DE POTASSIUM'),
#  (0.0, u'SULFATE DE POLYMYXINE B'),
#  ...]

# %% [markdown]
# # Calcul des predictions et soumission

# %%
# On entraine de nouveau le modèle, cette fois sur l'intégralité des données
#clf = ExtraTreesRegressor(n_estimators=11, max_features= 'auto', criterion="mse", max_depth=None, min_samples_split=5, n_jobs=-1)
clf.fit(X_train, y_train)

predictions = clf.predict(X_test)
if "log" in config["featToTransform"]:
    predictions = np.exp(predictions)

# %%
pd.DataFrame(predictions, index=test['id']).to_csv('submit/soumission.csv',  
                          header=['prix'],
                          sep = ';', 
                          dtypes={'id':'int','prix':'int'})
